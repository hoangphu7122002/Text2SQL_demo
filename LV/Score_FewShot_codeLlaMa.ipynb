# %%
# !nvidia-smi
# Out:
# Sun May 19 16:09:16 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.30.02              Driver Version: 530.30.02    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-80GB           Off| 00000000:07:00.0 Off |                    0 |
# | N/A   63C    P0              393W / 400W|  65860MiB / 81920MiB |    100%      Default |
# |                                         |                      |             Disabled |
# ...

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

# %%
# !ls
# Out:
# 0.json	   1344.json  1689.json  314.json  659.json
# 1000.json  1345.json  168.json	 315.json  65.json
# 1001.json  1346.json  1690.json  316.json  660.json
# 1002.json  1347.json  1691.json  317.json  661.json
# 1003.json  1348.json  1692.json  318.json  662.json
# 1004.json  1349.json  1693.json  319.json  663.json
# 1005.json  134.json   1694.json  31.json   664.json
# 1006.json  1350.json  1695.json  320.json  665.json
# 1007.json  1351.json  1696.json  321.json  666.json
# 1008.json  1352.json  1697.json  322.json  667.json
# 1009.json  1353.json  1698.json  323.json  668.json
# 100.json   1354.json  1699.json  324.json  669.json
# 1010.json  1355.json  169.json	 325.json  66.json
# 1011.json  1356.json  16.json	 326.json  670.json
# 1012.json  1357.json  1700.json  327.json  671.json
# 1013.json  1358.json  1701.json  328.json  672.json
# 1014.json  1359.json  1702.json  329.json  673.json
# 1015.json  135.json   1703.json  32.json   674.json
# ...

# %%
os.listdir("benchmark__FewShot_codeLlama_text2sql_syll_r128_2")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.listdir("benchmark__FewShot_codeLlama_text2sql_syll_r128_2")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'benchmark__FewShot_codeLlama_text2sql_syll_r128_2'
